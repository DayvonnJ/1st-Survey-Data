# %% [markdown]
# # Setting EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.graphics.mosaicplot import mosaic
import seaborn as sns
color = sns.color_palette()
# %matplotlib inline

import plotly.express as px
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import textwrap

pd.options.mode.chained_assignment = None
pd.options.display.max_columns = 999
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.26.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv('Scholar_Survey_Responses_Spring_2015.csv')
df
# Out:
#      Response Id Where did you attend SEO Scholars?  \
# 0          14531                             Site A
# 1          14730                             Site A
# 2          14579                             Site A
# 3          14583                             Site A
# 4          14709                             Site A
# ..           ...                                ...
# 326        13311                             Site C
# 327        13304                             Site C
# 328        13302                             Site C
# 329        13300                             Site C
# 330        13384                             Site C
#
#     High School Graduation Year (Class) Group  \
# 0                  Class of 2018 (CO18)     D
# 1                  Class of 2018 (CO18)     C
# 2                  Class of 2018 (CO18)     A
# 3                  Class of 2018 (CO18)     B
# 4                  Class of 2018 (CO18)     A
# ..                                  ...   ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331 entries, 0 to 330
# Columns: 110 entries, Response Id to Is there anything else you would like to tell us about your SEO experience? Please provide any comments you’d like to share below.
# dtypes: float64(2), int64(1), object(107)
# memory usage: 284.6+ KB

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.describe()
# Out:
#         Response Id  Not listed (Gender Identity)  \
# count    331.000000                           0.0
# mean   13658.474320                           NaN
# std      388.233351                           NaN
# min    13229.000000                           NaN
# 25%    13357.500000                           NaN
# 50%    13616.000000                           NaN
# 75%    13852.500000                           NaN
# max    14863.000000                           NaN
#
#        Please share the opening circle topics you enjoyed the most.
# count                                                0.0
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# ...

# %%
# Looking at the columns to understand what is happeneing
for col in df.columns:
    print(col)
list(df.columns)
# Out:
# Response Id
# Where did you attend SEO Scholars?
# High School Graduation Year (Class)
# Group
# Race/Ethnicity
# Not listed (Race/Ethnicity )
# Gender Identity:
# Not listed (Gender Identity)
# What do you like most about SEO?
# What do you dislike most about SEO?
# I enjoy coming to SEO most of the time.
# I try to do my best in my SEO courses.
# My instructors’ expectations make me want to do my best.
# What I learn in class helps me outside of SEO.
# I take pride in my SEO work.
# I am getting a high-quality education through SEO.
# My classmates at SEO are supportive of me.
# I am comfortable seeking assistance from my classmates at SEO.
# I feel connected to my peers at SEO.
# How would you rate the communication and support provided by SEO staff and instructors?
# Did SEO meet your expectations in terms of content and quality?
# Have you noticed any improvements in your academic performance since participating in SEO?
# I would recommend SEO Scholars to a friend.
# ...

# %%
df['Why or why not?'].value_counts()
# Out:
# Why or why not?
# It prepares you for college.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
# ...

# %%
#Examining to see if there are similar responses to the fill in question that could be grouped to show the mode
df['Why or why not?'].value_counts(normalize=True)
# Out:
# Why or why not?
# It prepares you for college.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            0.004902
# ...

# %%
#Converting Data into categories to help with size of file and iteration
conversion_dict = {k: "category" for k in df.select_dtypes(include="object").columns}
df=df.astype(conversion_dict)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331 entries, 0 to 330
# Columns: 110 entries, Response Id to Is there anything else you would like to tell us about your SEO experience? Please provide any comments you’d like to share below.
# dtypes: category(107), float64(2), int64(1)
# memory usage: 161.8 KB

# %% [markdown]
# ## Gender Identification Value Count and Clean Up

# %%
df['Gender Identity:'].value_counts()
# Out:
# Gender Identity:
# Woman                                                  175
# Man                                                    125
# Woman,Cisgender                                         13
# Non-Binary, Genderqueer or Gender-Fluid                  7
# Prefer not to say                                        6
# Non-Binary, Genderqueer or Gender-Fluid,Transgender      2
# Man,Cisgender                                            1
# Man,Transgender                                          1
# Woman,Non-Binary, Genderqueer or Gender-Fluid            1
# Name: count, dtype: int64

# %%
#Listed Types of Gender
df['Gender Identity:'].cat.categories
# Out:
# Index(['Man', 'Man,Cisgender', 'Man,Transgender',
#        'Non-Binary, Genderqueer or Gender-Fluid',
#        'Non-Binary, Genderqueer or Gender-Fluid,Transgender',
#        'Prefer not to say', 'Woman', 'Woman,Cisgender',
#        'Woman,Non-Binary, Genderqueer or Gender-Fluid'],
#       dtype='object')

# %%
new_gender_identity = {"Woman": "Woman",
                        "Man": "Man",
                        "Woman,Cisgender": "Cisgender",
                        "Man,Cisgender": "Cisgender",
                        "Man,Transgender": "Transgender",
                        "Non-Binary, Genderqueer or Gender-Fluid": "Non-Binary",
                        "Non-Binary, Genderqueer or Gender-Fluid,Transgender": "Non-Binary",
                        "Woman,Non-Binary, Genderqueer or Gender-Fluid": "Non-Binary",
                        "Prefer not to say": "Prefer not to say"}

# %%
#inserting a column of my simplified gender identity without removing the original column
df["gender_identity_clean"] = df["Gender Identity:"].replace(new_gender_identity).astype("category")

# %%
#new values
df["gender_identity_clean"].value_counts()
# Out:
# gender_identity_clean
# Woman                175
# Man                  125
# Cisgender             14
# Non-Binary            10
# Prefer not to say      6
# Transgender            1
# Name: count, dtype: int64

# %%
# Calculate gender distribution
temp_series_1 = df['gender_identity_clean'].value_counts()
labels = (np.array(temp_series_1.index))
sizes = (np.array((temp_series_1 / temp_series_1.sum())*100))
# Create a pie chart
trace = go.Pie(labels=labels, values=sizes)
layout = go.Layout(
    title='Gender Distribution'
)
data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="gender")
#Saving Image as JPEG
fig.write_image("gender.jpeg")

# Show the top 10 responses
top_10_responses_1 = temp_series_1.head(10)
print(top_10_responses_1)
# Out:
# gender_identity_clean
# Woman                175
# Man                  125
# Cisgender             14
# Non-Binary            10
# Prefer not to say      6
# Transgender            1
# Name: count, dtype: int64

# %% [markdown]
# ## Race Ethnicty Value Count and Clean Up

# %%
#Listed Types of Race/Ethnicity
df['Race/Ethnicity'].cat.categories
# Out:
# Index(['Asian or Pacific Islander', 'Asian or Pacific Islander,Latinx',
#        'Asian or Pacific Islander,Latinx,Multiracial',
#        'Asian or Pacific Islander,White,Multiracial',
#        'Black or African American', 'Black or African American,Latinx',
#        'Black or African American,Latinx,Multiracial',
#        'Black or African American,Latinx,Native American or Alaska Native',
#        'Black or African American,Middle Eastern or North African',
#        'Black or African American,Multiracial', 'Latinx',
#        'Latinx,Native American or Alaska Native,Multiracial',
#        'Middle Eastern or North African',
#        'Middle Eastern or North African,Not listed', 'Multiracial',
#        'Native American or Alaska Native', 'Not listed', 'Prefer not to say',
#        'White', 'White,Latinx'],
#       dtype='object')

# %%
new_race_ethnic_identity = {"Asian or Pacific Islander": "Asian or Pacific Islander",
                       "Black or African American": "Black or African American",
                       "Latinx": "Latinx",
                       "Middle Eastern or North African": "Middle Eastern or North African",
                       "Multiracial": "Two or More Ethnic/Race Backgrounds",
                       "Native American or Alaska Native": "Native American or Alaska Native",
                       "Not listed": "Not Listed",
                       "Prefer not to say": "Prefer not to say",
                       "White": "White",
                       "Asian or Pacific Islander,Latinx": "Two or More Ethnic/Race Backgrounds",
                       "Asian or Pacific Islander,Latinx,Multiracial": "Two or More Ethnic/Race Backgrounds",
                       "Asian or Pacific Islander,White,Multiracial": "Two or More Ethnic/Race Backgrounds",
                       "Black or African American,Latinx": "Two or More Ethnic/Race Backgrounds",
                       "Black or African American,Latinx,Multiracial": "Two or More Ethnic/Race Backgrounds",
                       "Black or African American,Multiracial": "Two or More Ethnic/Race Backgrounds",
                       "Black or African American,Latinx,Native American or Alaska Native": "Two or More Ethnic/Race Backgrounds",
                       "Black or African American,Middle Eastern or North African": "Two or More Ethnic/Race Backgrounds",
                       "Latinx,Native American or Alaska Native,Multiracial": "Two or More Ethnic/Race Backgrounds",
                       "Middle Eastern or North African,Not listed": "Two or More Ethnic/Race Backgrounds",
                       "White,Latinx": "Two or More Ethnic/Race Backgrounds",}

# %%
#inserting a column of my simplified race ethnic identity without removing the original column
df["race_ethnic_identity_clean"] = df["Race/Ethnicity"].replace(new_race_ethnic_identity).astype("category")

# %%
#new values
df["race_ethnic_identity_clean"].value_counts()
# Out:
# race_ethnic_identity_clean
# Latinx                                 137
# Asian or Pacific Islander               68
# Black or African American               65
# Two or More Ethnic/Race Backgrounds     32
# White                                   10
# Middle Eastern or North African          7
# Prefer not to say                        6
# Not Listed                               5
# Native American or Alaska Native         1
# Name: count, dtype: int64

# %%
#Race/Ethnicity Graph
temp_series_2 = df['race_ethnic_identity_clean'].value_counts()
labels = (np.array(temp_series_2.index))
sizes = (np.array((temp_series_2 / temp_series_2.sum())*100))

trace = go.Pie(labels=labels, values=sizes)
layout = go.Layout(
    title='Race/Ethnic Distribution'
)
data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="race_ethnic")
#Saving Image as JPEG
fig.write_image("race_ethnic.jpeg")

# Show the top 10 responses
top_10_responses_2 = temp_series_2.head(10)
print(top_10_responses_2)
# Out:
# race_ethnic_identity_clean
# Latinx                                 137
# Asian or Pacific Islander               68
# Black or African American               65
# Two or More Ethnic/Race Backgrounds     32
# White                                   10
# Middle Eastern or North African          7
# Prefer not to say                        6
# Not Listed                               5
# Native American or Alaska Native         1
# Name: count, dtype: int64

# %% [markdown]
# ## SEO Experience Graphs

# %%
# Load your survey data from the specified CSV file
df = pd.read_csv('Scholar_Survey_Responses_Spring_2015.csv')
# Define the statements and their corresponding response categories
statements = [
    "I enjoy coming to SEO most of the time.",
    "I try to do my best in my SEO courses.",
    "My instructors’ expectations make me want to do my best.",
    "What I learn in class helps me outside of SEO.",
    "I take pride in my SEO work.",
    "I am getting a high-quality education through SEO.",
    "My classmates at SEO are supportive of me.",
    "I am comfortable seeking assistance from my classmates at SEO.",
    "I feel connected to my peers at SEO."
]

response_categories_1 = ["Strongly Disagree", "Disagree", "Agree", "Strongly Agree"]

# Initialize lists to store the counts for each response category
response_counts = {category: [] for category in response_categories_1}

# Iterate through the statements
for statement in statements:
    # Get the value counts for the current statement
    cnt_srs_1 = df[statement].value_counts()
    
    # Append the counts for each response category to the respective list
    for category in response_categories_1:
        response_counts[category].append(cnt_srs_1.get(category, 0))

# Create bar chart traces for each response category
traces = []
for category in response_categories_1:
    trace = go.Bar(
        y=statements,
        x=response_counts[category],
        orientation='h',
        name=category
    )
    traces.append(trace)

# Create the layout
layout = go.Layout(
    title='SEO Experience Review',
    barmode='stack',
    width=1000,
    height=600
)

# Create the figure
fig = go.Figure(data=traces, layout=layout)

# Show the plot
fig.show()
# Save the figure as an HTML file
fig.write_html("seo_experience.html")
#Saving Image as JPEG
fig.write_image("seo_experience.jpeg")

# %%
# Specify the column name
column_name_1 = 'How would you rate the communication and support provided by SEO staff and instructors?'

# Get the value counts for the ratings
rating_counts_1 = df[column_name_1].value_counts().head()

# Create a DataFrame for the top 5 responses
top_5_responses_2 = pd.DataFrame({'Rating': rating_counts_1.index, 'Count': rating_counts_1.values})

# Create the bar chart for the top 5 responses using Plotly Express
fig_top_1 = px.bar(top_5_responses_2, x='Rating', y='Count', color='Count',
                   title='Staff Communication Effectiveness Ratings',
                   labels={'Rating': 'Rating'},
                   color_continuous_scale='Rainbow',
                   height=600)

# Specify the order of categories on the x-axis
fig_top_1.update_xaxes(categoryorder='array', categoryarray=['Poor', 'Fair', 'Good', 'Excellent'])

# Add text labels to the bars for counts
fig_top_1.update_traces(text=top_5_responses_2['Count'], textposition='outside')

# Saving the top 5 responses chart as a JPEG
fig_top_1.write_image("staff_communication_effectiveness.jpeg")

# Show the top 5 responses chart
fig_top_1.show()

# %%
# Specify the column name
column_name_2 = 'Have you noticed any improvements in your academic performance since participating in SEO?'

# Get the value counts for the responses
cnt_srs_2 = df[column_name_2].value_counts()

# Create the pie chart
trace = go.Pie(
    labels=cnt_srs_2.index,
    values=cnt_srs_2.values,
    marker=dict(colors=['blue', 'green', 'red', 'purple']),
)

layout = go.Layout(
    title='Understanding of improvements in academic performance',
)

data = [trace]
fig = go.Figure(data=data, layout=layout)

# Display the pie chart
fig.show()

# Save the pie chart as a JPEG file
fig.write_image("academic_performance_improvements.jpeg")

# Show the top 5 responses
top_5_responses_3 = cnt_srs_2.head(5)
print("Top 5 Responses:")
print(top_5_responses_3)
# Out:
# Top 5 Responses:
# Have you noticed any improvements in your academic performance since participating in SEO?
# I have not noticed any significant changes in my academic performance.    104
# I have seen slight improvements in my academic performance.               102
# I have experienced noticeable improvements in my academic performance.    101
# My academic performance has significantly improved.                        13
# My academic performance has worsened.                                      11
# Name: count, dtype: int64

# %% [markdown]
# ### Testing A Different Type of Chart for the Data

# %%
# Specify the column name
column_name_3 = 'Have you noticed any improvements in your academic performance since participating in SEO?'

# Get the value counts for the responses
cnt_srs_3 = df[column_name_3].value_counts()

trace = go.Scatter(
    x=cnt_srs_3.index,
    y=cnt_srs_3.values,
    mode='markers',
    marker=dict(
        symbol='triangle-up',
        sizemode='diameter',
        sizeref=3,
        size=25,
        color=cnt_srs_3.values,
        colorscale='Rainbow',
        showscale=True
    ),
)

layout = go.Layout(
    title='Understanding of improvements in academic performance',
)

data = [trace]
fig = go.Figure(data=data, layout=layout)

# Display the chart
fig.show()

# Save the chart as a JPEG file
fig.write_image("academic_performance_improvements.jpeg")

# Optionally, you can also print the top responses
top_responses = cnt_srs_3.head()
print("Top Responses:")
print(top_responses)
# Out:
# Top Responses:
# Have you noticed any improvements in your academic performance since participating in SEO?
# I have not noticed any significant changes in my academic performance.    104
# I have seen slight improvements in my academic performance.               102
# I have experienced noticeable improvements in my academic performance.    101
# My academic performance has significantly improved.                        13
# My academic performance has worsened.                                      11
# Name: count, dtype: int64

# %%
# Specify the column name
column_name_4 = 'I would recommend SEO Scholars to a friend.'

# Get the value counts for the responses
cnt_srs_4 = df[column_name_4].value_counts()

# Create the pie chart
trace = go.Pie(
    labels=cnt_srs_4.index,
    values=cnt_srs_4.values,
    marker=dict(colors=['blue', 'green', 'red', 'purple']),
)

layout = go.Layout(
    title='Recommending SEO Scholars to Peers',
)

data = [trace]
fig = go.Figure(data=data, layout=layout)

# Display the pie chart in Jupyter Notebook or in a standalone HTML file
fig.show()

# Save the pie chart as an JPEG file
fig.write_image("recommending_seo.jpeg")
# Show the top 5 responses
top_5_responses_4 = cnt_srs_4.head(5)
print(top_5_responses_4)
# Out:
# I would recommend SEO Scholars to a friend.
# Agree                141
# Strongly Agree        89
# Disagree              15
# Strongly Disagree      1
# Name: count, dtype: int64

# %%
# Define the statements with the problematic character and their corresponding response categories
statements = [
    "Because your instructors ask or tell you to?",
    "Even when your instructor doesn't ask or tell you to?"
]

response_categories_2 = ["Never", "Rarely", "Sometimes", "Always"]

# Initialize lists to store the counts for each response category
response_counts = {category: [] for category in response_categories_2}

# Iterate through the statements
for statement in statements:
    # Get the value counts for the current statement
    cnt_srs_5 = df[statement].value_counts()
    
    # Append the counts for each response category to the respective list
    for category in response_categories_2:
        response_counts[category].append(cnt_srs_5.get(category, 0))

# Create bar chart traces for each response category
traces = []
for category in response_categories_2:
    trace = go.Bar(
        y=statements,
        x=response_counts[category],
        orientation='h',
        name=category
    )
    traces.append(trace)

# Create the layout
layout = go.Layout(
    title='How often do you work in teams of other students?',
    barmode='stack',
    width=800,
    height=600
)

# Create the figure
fig = go.Figure(data=traces, layout=layout)

# Display the plot
fig.show()

# Save the figure as an HTML file
fig.write_html("working_in_teams.html")

# Save the figure as an image
fig.write_image("working_in_teams.jpeg")

# %%
# Define the statements and their corresponding response categories
statements = [
    "Most students at SEO want to do well in class.",
    "I really feel like part of the SEO community.",
    "I can usually be myself around other students at SEO.",
    "Most students at SEO are friendly to me.",
    "Most adults at SEO treat students with respect.",
    "Discipline at SEO is fair.",
    "Adults at SEO respect people from different backgrounds (e.g. people of different races, ethnicities, and genders)."
]

response_categories_1 = ["Strongly Disagree", "Disagree", "Agree", "Strongly Agree"]

# Initialize lists to store the counts for each response category
response_counts = {category: [] for category in response_categories_1}

# Iterate through the statements
for statement in statements:
    # Get the value counts for the current statement
    cnt_srs_6 = df[statement].value_counts()
    
    # Append the counts for each response category to the respective list
    for category in response_categories_1:
        response_counts[category].append(cnt_srs_6.get(category, 0))

# Create bar chart traces for each response category
traces = []
for category in response_categories_1:
    trace = go.Bar(
        y=[textwrap.fill(label, width=20) for label in statements],  # Wrap long text
        x=response_counts[category],
        orientation='h',
        name=category
    )
    traces.append(trace)

# Create the layout
layout = go.Layout(
    title='Emotional Experience of Program',
    barmode='group',
    width=1000,
    height=600
)

# Create the figure
fig = go.Figure(data=traces, layout=layout)

# Show the plot
fig.show()
# Save the figure as an HTML file
fig.write_html("emotional_experience.html")
#Saving Image as JPEG
fig.write_image("emotional_experience.jpeg")

# %%
# Hybrid In Person or Remote
cnt_srs_7 = df['If given the option, I believe that Weekday programming should:'].value_counts()

trace = go.Scatter(
    x=cnt_srs_7.index,
    y=cnt_srs_7.values,
    mode='markers',
    marker=dict(
        sizemode = 'diameter',
        sizeref = 3,
        size = cnt_srs_7.values,
        #color = np.random.randn(500), #set color equal to a variable
        color = cnt_srs_7.values,
        colorscale='Portland',
        showscale=False
    ),
)

layout = go.Layout(
    title='Preference for Weekday Programming Attendance'
)

data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="programming_attendance_preference")
# Save the scatter plot as an JPEG file
fig.write_image("recommending_seo.jpeg")
# Show the top 5 responses
top_5_responses_5 = cnt_srs_7.head(5)
print(top_5_responses_5)
# Out:
# If given the option, I believe that Weekday programming should:
# Be fully online                                           118
# Remain in-person                                           92
# A hybrid of both in-person and online                      77
# Be fully online,A hybrid of both in-person and online      11
# Remain in-person,A hybrid of both in-person and online      8
# Name: count, dtype: int64

# %% [markdown]
# ## Brightspace and Learning Tools Experience

# %% [markdown]
# ### Navigating Platforms at SEO

# %%
# Load your survey data from the specified CSV file
df = pd.read_csv('Scholar_Survey_Responses_Spring_2015.csv')
# Define the statements and their corresponding response categories
statements = [
    "Brightspace",
    "Desmos",
    "Hypothesis",
    "Nearpod",
]

response_categories_2 = ["Very Difficult", "Moderately Dificult", "Moderately Easy", "Very Easy", "N/A"]

# Initialize lists to store the counts for each response category
response_counts = {category: [] for category in response_categories_2}

# Iterate through the statements
for statement in statements:
    # Get the value counts for the current statement
    cnt_srs_8 = df[statement].value_counts()
    
    # Append the counts for each response category to the respective list
    for category in response_categories_2:
        response_counts[category].append(cnt_srs_8.get(category, 0))

# Create bar chart traces for each response category
traces = []
for category in response_categories_2:
    trace = go.Bar(
        y=statements,
        x=response_counts[category],
        orientation='h',
        name=category
    )
    traces.append(trace)

# Create the layout
layout = go.Layout(
    title='Brightspace Learning Tools Experience',
    barmode='stack',
    width=800,
    height=600
)

# Create the figure
fig = go.Figure(data=traces, layout=layout)

# Show the plot
fig.show()
# Save the figure as an HTML file
fig.write_html("brightspace_tools.html")

# %%
# Define the statements and their corresponding response categories
statements = [
    "Navigating in and out of your Math courses to access ELA content",
    "Navigating in and out of your ELA courses to access Math content",
    "Process of submitting your Math assignments",
    "Process of submitting your ELA assignments",
    "Accessing your grades and instructor feedback on your work"
]

response_categories_3 = ["Very Difficult", "Moderately Dificult", "Moderately Easy", "Very Easy", "N/A"]

# Initialize lists to store the counts for each response category
response_counts = {category: [] for category in response_categories_3}

# Iterate through the statements
for statement in statements:
    # Get the value counts for the current statement
    cnt_srs_9 = df[statement].value_counts()
    
    # Append the counts for each response category to the respective list
    for category in response_categories_2:
        response_counts[category].append(cnt_srs_9.get(category, 0))

# Create bar chart traces for each response category
traces = []
for category in response_categories_2:
    trace = go.Bar(
        y=statements,
        x=response_counts[category],
        orientation='h',
        name=category
    )
    traces.append(trace)

# Create the layout
layout = go.Layout(
    title='Brightspace Overall Experience',
    barmode='stack',
    width=800,
    height=600
)

# Create the figure
fig = go.Figure(data=traces, layout=layout)

# Show the plot
fig.show()
# Save the figure as an HTML file
fig.write_html("brightspace_experience.html")
#Saving Image as JPEG
fig.write_image("brightspace_experience.jpeg")

# %% [markdown]
# # SEO Academic Experience

# %%
# Load your survey data from the specified CSV file
df = pd.read_csv('Scholar_Survey_Responses_Spring_2015.csv')# Specify the column name
column_name_5 = 'Out of the following options, what motivates you most to learn?'

# Get the value counts for the responses
cnt_srs_10 = df[column_name_5].value_counts()

# Create the pie chart
trace = go.Pie(
    labels=cnt_srs_10.index,
    values=cnt_srs_10.values,
    marker=dict(colors=['blue', 'green', 'red', 'purple', 'yellow','black']),
)

layout = go.Layout(
    title='Out of the following options, what motivates you most to learn?',
)

data = [trace]
fig = go.Figure(data=data, layout=layout)

# Display the pie chart in Jupyter Notebook or in a standalone HTML file
fig.show()

# Save the pie chart as an JPEG file
fig.write_image("motivation_to_learn.jpeg")
# Show the top 5 responses
top_5_responses_6 = cnt_srs_10.head(5)
print(top_5_responses_6)
# Out:
# Out of the following options, what motivates you most to learn?
# Intrinsic motivation - When I have genuine interest in the topic                       116
# Goal setting - When I set clear, achievable objectives                                  68
# Praise - When I get timely recognition for hard work and growth                         45
# Real-life relevance - When lessons incorporate real-world applications and examples     43
# Social connections - When I have positive peer and teacher relationships                41
# Name: count, dtype: int64

# %%
# Specify the column name
column_name_6 = 'How much time do you spend every day on school homework?'

# Get the value counts for the responses
cnt_srs_11 = df[column_name_6].value_counts().head(7)  # All 7 responses

# Create the bar chart
trace = go.Bar(
    x=cnt_srs_11.index,
    y=cnt_srs_11.values,
    marker=dict(color=['blue', 'green', 'red', 'purple', 'yellow']),
)

layout = go.Layout(
    title='5 Responses of Daily Time (Mon-Fri) Spent on School Homework',
    xaxis=dict(title='Response'),
    yaxis=dict(title='Count'),
)

data = [trace]
fig = go.Figure(data=data, layout=layout)

# Display the bar chart in Jupyter Notebook or in a standalone HTML file
fig.show()

# Save the bar chart as an JPEG file
fig.write_image("time_spent_learning.jpeg")

# Show the top 5 responses
print(cnt_srs_11)
# Out:
# How much time do you spend every day on school homework?
# <2 Hours     125
# 2-3 Hours    108
# 3-4 Hours     63
# 4-5 Hours     22
# >5 Hours      13
# Name: count, dtype: int64

# %%
# Specify the column name
column_name_7 = 'How much time do you spend every day on SEO assignments?'

# Get the value counts for the responses
cnt_srs_12 = df[column_name_7].value_counts().head()  # All responses

# Create the bar chart
trace = go.Bar(
    x=cnt_srs_12.index,
    y=cnt_srs_12.values,
    marker=dict(color=['blue', 'green', 'red', 'purple', 'black']),
)

layout = go.Layout(
    title='4 Responses of Daily Time (Mon-Fri) Spent on SEO Assignments',
    xaxis=dict(title='Response'),
    yaxis=dict(title='Count'),
)

data = [trace]
fig = go.Figure(data=data, layout=layout)

# Display the bar chart in Jupyter Notebook or in a standalone HTML file
fig.show()

# Save the bar chart as an JPEG file
fig.write_image("time_spent_on_seo_assignments.jpeg")

# Show the top 5 responses
print(cnt_srs_12)
# Out:
# How much time do you spend every day on SEO assignments?
# <2 Hours     210
# 2-3 Hours    101
# 3-4 Hours     16
# 4-5 Hours      4
# Name: count, dtype: int64

# %%
column_name_8 = 'How often do you experience situations or challenges that make it difficult to learn at home?'

# Get the value counts for the responses
cnt_srs_13 = df[column_name_8].value_counts()

# Create the pie chart
trace = go.Pie(
    labels=cnt_srs_13.index,
    values=cnt_srs_13.values,
    marker=dict(colors=['blue', 'green', 'red', 'purple', 'yellow','black']),
)

layout = go.Layout(
    title='Frequency of situations or challenges that make it difficult to learn at home?',
)

data = [trace]
fig = go.Figure(data=data, layout=layout)

# Display the pie chart in Jupyter Notebook or in a standalone HTML file
fig.show()

# Save the pie chart as an JPEG file
fig.write_image("challenges_at_home_to_learn.jpeg")
# Show the top 5 responses
top_5_responses_7 = cnt_srs_13.head(5)
print(top_5_responses_7)
# Out:
# How often do you experience situations or challenges that make it difficult to learn at home?
# Sometimes    147
# Rarely       130
# Never         29
# Always        25
# Name: count, dtype: int64

# %%
# Specify the column name
column_name_9 = 'How would you evaluate your overall academic experience with your instructors this semester?'

# Get the value counts for the ratings
rating_counts_2 = df[column_name_9].value_counts().head()

# Create a DataFrame for the top 5 responses
top_5_responses_8 = pd.DataFrame({'Rating': rating_counts_2.index, 'Count': rating_counts_2.values})

# Create the bar chart for the top 5 responses using Plotly Express
fig_top_2 = px.bar(top_5_responses_8, x='Rating', y='Count', color='Count',
                   title='Academic Experience with Instructors for the Semester Ratings',
                   labels={'Rating': 'Rating'},
                   color_continuous_scale='Rainbow',
                   height=500)

# Specify the order of categories on the x-axis
fig_top_2.update_xaxes(categoryorder='array', categoryarray=['Very Dissatisfied', 'Not Satisfied', 'Satisfied', 'Very Satisfied'])

# Add text labels to the bars for counts
fig_top_2.update_traces(text=top_5_responses_8['Count'], textposition='outside')

# Saving the top 5 responses chart as a JPEG
fig_top_2.write_image("academic_experience_with_instructors_for_semester.jpeg")

# Show the top 5 responses chart
fig_top_2.show()

# %%
# Define the statements and their corresponding response categories
statements = [
    "My instructors have fair rules for the class and are extremely impartial.",
    "My instructors ask each one of us whether we have understood what they taught and help us in case we have doubts."
]

response_categories_1 = ["Strongly Disagree", "Disagree", "Agree", "Strongly Agree"]

# Initialize lists to store the counts for each response category
response_counts = {category: [] for category in response_categories_1}

# Iterate through the statements
for statement in statements:
    # Get the value counts for the current statement
    cnt_srs_14 = df[statement].value_counts()
    
    # Append the counts for each response category to the respective list
    for category in response_categories_1:
        response_counts[category].append(cnt_srs_14.get(category, 0))

# Create bar chart traces for each response category
traces = []
for category in response_categories_1:
    trace = go.Bar(
        y=[textwrap.fill(label, width=20) for label in statements],  # Wrap long text
        x=response_counts[category],
        orientation='h',
        name=category
    )
    traces.append(trace)

# Create the layout
layout = go.Layout(
    title='Statements on Instructors',
    barmode='group',
    width=1000,
    height=600
)

# Create the figure
fig = go.Figure(data=traces, layout=layout)

# Show the plot
fig.show()
# Save the figure as an HTML file
fig.write_html("instructor_statements.html")
#Saving Image as JPEG
fig.write_image("instructor_statements.jpeg")

# %%
# Define the statements with the problematic character and their corresponding response categories
statements = [
    "Did your instructors guide you in setting personal targets and developing strategies to achieve that target?",
    "Even when your instructor doesn't ask or tell you to?",
    "After each assignment, did your instructor help you in understanding ways to improve your work?",
    "Try to be fair?",
    "Are willing to give extra help on work if you need it?",
    "Are not just satisfied if you pass they care if you are really learning?",
    "Believe that you can get a good grade if you try?",
    "Connect what you are learning in class with your life outside of SEO?",
    "Make an effort to understand what your life is like outside of SEO?"
]

response_categories_2 = ["Never", "Rarely", "Sometimes", "Always"]

# Initialize lists to store the counts for each response category
response_counts = {category: [] for category in response_categories_2}

# Iterate through the statements
for statement in statements:
    # Get the value counts for the current statement
    cnt_srs_15 = df[statement].value_counts()
    
    # Append the counts for each response category to the respective list
    for category in response_categories_2:
        response_counts[category].append(cnt_srs_15.get(category, 0))

# Create bar chart traces for each response category
traces = []
for category in response_categories_2:
    trace = go.Bar(
        y=[textwrap.fill(label, width=20) for label in statements],  # Wrap long text
        x=response_counts[category],
        orientation='h',
        name=category
    )
    traces.append(trace)

# Create the layout
layout = go.Layout(
    title='Instructor Behavioral Frequency Experience',
    barmode='stack',
    width=1000,
    height=600
)

# Create the figure
fig = go.Figure(data=traces, layout=layout)

# Display the plot
fig.show()

# Save the figure as an HTML file
fig.write_html("instructor_behavioral_frequency_experience.html")

# Save the figure as an image
fig.write_image("instructor_behavioral_frequency_experience.jpeg")

# %% [markdown]
# # SEO Math Experience

# %%
# Load your survey data from the specified CSV file
df = pd.read_csv('Scholar_Survey_Responses_Spring_2015.csv')

# Define the statements and their corresponding response categories
statements = [
    "The work that I do for my math classes is challenging and pushes me to learn new concepts and skills.",
    "I look forward to my math class and this makes me happy that I joined SEO.",
    "What I learned in this course is valuable to me.",
    "I knew how to find math resources to help support my progress in this class.",
    "When asked to work with my classmates on a math problem, I contributed to conversations and shared my ideas.",
    "I found it helpful to work with my classmates on math problems."
]

response_categories_1 = ["Strongly Disagree", "Disagree", "Agree", "Strongly Agree"]

# Initialize lists to store the counts for each response category
response_counts = {category: [] for category in response_categories_1}

# Iterate through the statements
for statement in statements:
    # Get the value counts for the current statement
    cnt_srs_16 = df[statement].value_counts()
    
    # Append the counts for each response category to the respective list
    for category in response_categories_1:
        response_counts[category].append(cnt_srs_16.get(category, 0))

# Create bar chart traces for each response category
traces = []
for i, category in enumerate(response_categories_1):
    trace = go.Bar(
        y=[textwrap.fill(label, width=20) for label in statements],  # Wrap long text
        x=response_counts[category],
        orientation='h',
        name=category,
    )
    traces.append(trace)

# Create the layout
layout = go.Layout(
    title='SEO Math Experience Review',
    barmode='group',
    width=1000,
    height=600
)

# Create the figure
fig = go.Figure(data=traces, layout=layout)

# Show the plot
fig.show()

# Save the figure as an HTML file
fig.write_html("seo_math_experience.html")

# Saving Image as JPEG
fig.write_image("seo_math_experience.jpeg")

# %% [markdown]
# # Math Instructor Evaluation

# %%
# Load your survey data from the specified CSV file
df = pd.read_csv('Scholar_Survey_Responses_Spring_2015.csv')

# Define the statements and their corresponding response categories
statements = [
    "My instructors made the material accessible for my needs as a learner.",
    "The instructors explained concepts clearly and increased my level of understanding of the course material.",
    "The questions my instructors asked challenged me to think more deeply and/or more critically.",
    "My instructors valued and encouraged my engagement in the classroom.",
    "I received feedback on my work that was helpful and timely.",
    "I feel seen, appreciated, and valued by my instructors.",
    "I know my instructors believe in my ability to be academically successful.",
    "I can tell that my Math instructor(s) understand the subjects that they are teaching."
]

response_categories_1 = ["Strongly Disagree", "Disagree", "Agree", "Strongly Agree"]

# Initialize lists to store the counts for each response category
response_counts = {category: [] for category in response_categories_1}

# Iterate through the statements
for statement in statements:
    # Get the value counts for the current statement
    cnt_srs_17 = df[statement].value_counts()
    
    # Append the counts for each response category to the respective list
    for category in response_categories_1:
        response_counts[category].append(cnt_srs_17.get(category, 0))

# Create bar chart traces for each response category
traces = []
for i, category in enumerate(response_categories_1):
    trace = go.Bar(
        y=[textwrap.fill(label, width=20) for label in statements],  # Wrap long text
        x=response_counts[category],
        orientation='h',
        name=category,
    )
    traces.append(trace)

# Create the layout
layout = go.Layout(
    title='Math Instructor Evaluation',
    barmode='stack',
    width=1000,
    height=600
)

# Create the figure
fig = go.Figure(data=traces, layout=layout)

# Show the plot
fig.show()

# Save the figure as an HTML file
fig.write_html("math_instructor_evaluation.html")

# Saving Image as JPEG
fig.write_image("math_instructor_evaluation.jpeg")

# %% [markdown]
# # SEO ELA Experience

# %%
# Load your survey data from the specified CSV file
df = pd.read_csv('Scholar_Survey_Responses_Spring_2015.csv')

# Define the statements and their corresponding response categories
statements = [
    "The work that I do for my ELA classes is challenging and pushes me to learn new concepts and skills.",
    "I look forward to my ELA class and this makes me happy that I joined SEO.",
    "What I learned in this course is valuable to me.",
    "I knew how to find ELA resources to help support my progress in this class."
]

response_categories_1 = ["Strongly Disagree", "Disagree", "Agree", "Strongly Agree"]

# Initialize lists to store the counts for each response category
response_counts = {category: [] for category in response_categories_1}

# Iterate through the statements
for statement in statements:
    # Get the value counts for the current statement
    cnt_srs_18 = df[statement].value_counts()
    
    # Append the counts for each response category to the respective list
    for category in response_categories_1:
        response_counts[category].append(cnt_srs_18.get(category, 0))

# Create bar chart traces for each response category
traces = []
for i, category in enumerate(response_categories_1):
    trace = go.Bar(
        y=[textwrap.fill(label, width=20) for label in statements],  # Wrap long text
        x=response_counts[category],
        orientation='h',
        name=category,
    )
    traces.append(trace)

# Create the layout
layout = go.Layout(
    title='SEO ELA Experience',
    barmode='group',
    width=1000,
    height=600
)

# Create the figure
fig = go.Figure(data=traces, layout=layout)

# Show the plot
fig.show()

# Save the figure as an HTML file
fig.write_html("seo_ela_experience.html")

# Saving Image as JPEG
fig.write_image("seo_ela_experience.jpeg")

# %% [markdown]
# # ELA Instructor Evaluation

# %%
# Load your survey data from the specified CSV file
df = pd.read_csv('Scholar_Survey_Responses_Spring_2015.csv')

# Define the statements and their corresponding response categories
statements = [
    "My instructors made the material accessible for my needs as a learner.",
    "The instructors explained concepts clearly and increased my level of understanding of the course material.",
    "The questions my instructors asked challenged me to think more deeply and/or more critically.",
    "My instructors valued and encouraged my engagement in the classroom.",
    "I received feedback on my work that was helpful and timely.",
    "I feel seen, appreciated, and valued by my instructors.",
    "I know my instructors believe in my ability to be academically successful.",
    "I can tell that my ELA instructor(s) understand the subjects that they are teaching."
]

response_categories_1 = ["Strongly Disagree", "Disagree", "Agree", "Strongly Agree"]

# Initialize lists to store the counts for each response category
response_counts = {category: [] for category in response_categories_1}

# Iterate through the statements
for statement in statements:
    # Get the value counts for the current statement
    cnt_srs_19 = df[statement].value_counts()
    
    # Append the counts for each response category to the respective list
    for category in response_categories_1:
        response_counts[category].append(cnt_srs_19.get(category, 0))

# Create bar chart traces for each response category
traces = []
for i, category in enumerate(response_categories_1):
    trace = go.Bar(
        y=[textwrap.fill(label, width=20) for label in statements],  # Wrap long text
        x=response_counts[category],
        orientation='h',
        name=category,
    )
    traces.append(trace)

# Create the layout
layout = go.Layout(
    title='ELA Instructor Evaluation',
    barmode='stack',
    width=1000,
    height=600
)

# Create the figure
fig = go.Figure(data=traces, layout=layout)

# Show the plot
fig.show()

# Save the figure as an HTML file
fig.write_html("ela_instructor_evaluation.html")

# Saving Image as JPEG
fig.write_image("ela_instructor_evaluation.jpeg")

# %% [markdown]
# # Advisory/IE Experience

# %%
# Load your survey data from the specified CSV file
df = pd.read_csv('Scholar_Survey_Responses_Spring_2015.csv')
# Specify the column name
column_name_10 = 'This semester, how would you rate your Advisory/IE class experience at SEO?'

# Get the value counts for the ratings
rating_counts_3 = df[column_name_10].value_counts().head()

# Create a DataFrame for the top 5 responses
top_5_responses_9 = pd.DataFrame({'Rating': rating_counts_3.index, 'Count': rating_counts_3.values})

# Create the bar chart for the top 5 responses using Plotly Express
fig_top_3 = px.bar(top_5_responses_8, x='Rating', y='Count', color='Count',
                   title='Advisory/IE Class Experience Ratings',
                   labels={'Rating': 'Rating'},
                   color_continuous_scale='Rainbow',
                   height=500)

# Specify the order of categories on the x-axis
fig_top_3.update_xaxes(categoryorder='array', categoryarray=['Poor', 'Fair', 'Good', 'Excellent'])

# Add text labels to the bars for counts
fig_top_3.update_traces(text=top_5_responses_9['Count'], textposition='outside')

# Saving the top 5 responses chart as a JPEG
fig_top_3.write_image("advisory_ie_class_experience_ratings.jpeg")

# Show the top 5 responses chart
fig_top_3.show()

# %% [markdown]
# # Program Manager/Student Advisor Experience

# %%
# Load your survey data from the specified CSV file
df = pd.read_csv('Scholar_Survey_Responses_Spring_2015.csv')
# Define the statements and their corresponding response categories
statements = [
    "How would you rate your opening circle experience in your most recent semester?",
    "How would you rate your academic or college advising experience in your most recent semester?"
]

response_categories_4 = ["Poor", "Fair", "Good", "Excellent"]

# Initialize lists to store the counts for each response category
response_counts = {category: [] for category in response_categories_4}

# Iterate through the statements
for statement in statements:
    # Get the value counts for the current statement
    cnt_srs_20 = df[statement].value_counts()
    
    # Append the counts for each response category to the respective list
    for category in response_categories_4:
        response_counts[category].append(cnt_srs_20.get(category, 0))

# Create bar chart traces for each response category
traces = []
for category in response_categories_4:
    trace = go.Bar(
        y=[textwrap.fill(label, width=20) for label in statements],  # Wrap long text
        x=response_counts[category],
        orientation='h',
        name=category
    )
    traces.append(trace)

# Create the layout
layout = go.Layout(
    title='Program Manager/Student Advisor Experience',
    barmode='stack',
    width=1000,
    height=600
)

# Create the figure
fig = go.Figure(data=traces, layout=layout)

# Show the plot
fig.show()
# Save the figure as an HTML file
fig.write_html("program_manager_student_advisor_experience.html")
#Saving Image as JPEG
fig.write_image("program_manager_student_advisor_experience.jpeg")

# %%
# Define the statements and their corresponding response categories
statements = [
    "I felt supported and known by my Program Manager/Student Advisor.",
    "I felt comfortable going to my Program Manager/Student Advisor if I had a question or problem.",
    "My Program Manager/Student Advisor was engaging and well-prepared during the Opening Circle.",
    "The Program Manager/Student Advisor Hour sessions were useful to me.",
    "My Program Manager/Student Advisor did a good job building community with me and my SEO peers.",
    "I feel like I had the right amount of 1-on-1 advising meetings with my Program Manager/Student Advisor."
]

response_categories_1 = ["Strongly Disagree", "Disagree", "Agree", "Strongly Agree"]

# Initialize lists to store the counts for each response category
response_counts = {category: [] for category in response_categories_1}

# Iterate through the statements
for statement in statements:
    # Get the value counts for the current statement
    cnt_srs_21 = df[statement].value_counts()
    
    # Append the counts for each response category to the respective list
    for category in response_categories_1:
        response_counts[category].append(cnt_srs_21.get(category, 0))

# Create bar chart traces for each response category
traces = []
for category in response_categories_1:
    trace = go.Bar(
        y=[textwrap.fill(label, width=20) for label in statements],  # Wrap long text
        x=response_counts[category],
        orientation='h',
        name=category
    )
    traces.append(trace)

# Create the layout
layout = go.Layout(
    title='Program Manager/Student Advisor Experience Review',
    barmode='stack',
    width=1000,
    height=600
)

# Create the figure
fig = go.Figure(data=traces, layout=layout)

# Show the plot
fig.show()
# Save the figure as an HTML file
fig.write_html("program_manager_student_advisor_review.html")
#Saving Image as JPEG
fig.write_image("program_manager_student_advisor_review.jpeg")
